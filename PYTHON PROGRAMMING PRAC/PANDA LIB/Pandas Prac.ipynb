# %%
## Panda Pandas is a powerful and open-source Python library designed for data manipulation 
# and analysis. It is well-suited for working with tabular data, such as spreadsheets etc

# %%
import numpy as np
import pandas as pd

# %%
 # SERIES

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8]) 
# A one-dimensional labeled array capable of holding data of any type. good for one column.
# like (integer, string, float, Python objects, etc.). 
# It is similar to a column in an Excel sheet
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s.values
# Out:
# array([ 1.,  3.,  5., nan,  6.,  8.])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
s2 = pd.Series([4,6,8,10,12])

# %%
s2.index = ['a','b','c','d','e']

# %%
s2
# Out:
# a     4
# b     6
# c     8
# d    10
# e    12
# dtype: int64

# %%
## DATAFRAME

# %%
dic1 = {
    "name":['Gauurav','Rohan','Jeetu','Bittu'],
    "marks":[47,67,83,91],
    "city":['jamshedpur','bithoor','pulgaon','jagdalpur']
}

# %%
data = pd.DataFrame(dic1) #convert dictionary into an excelsheet i.e csv file 
# A two-dimensional data structure with labeled axes (rows and columns),
# similar to a table in a database or an Excelsheet

# %%
data
# Out:
#       name  marks        city
# 0  Gauurav     47  jamshedpur
# 1    Rohan     67     bithoor
# 2    Jeetu     83     pulgaon
# 3    Bittu     91   jagdalpur

# %%
data.to_csv('bhos.csv') #after analysing data, you want to put on excelsheet then use to_csv

# %%
data.to_csv('bhos1.csv',index = False)

# %%
data.head(1)
# Out:
#       name  marks        city
# 0  Gauurav     47  jamshedpur

# %%
data.tail(1)
# Out:
#     name  marks       city
# 3  Bittu     91  jagdalpur

# %%
data.describe() # gives you statistics only for numerical columns.
# Out:
#           marks
# count   4.00000
# mean   72.00000
# std    19.42507
# min    47.00000
# 25%    62.00000
# 50%    75.00000
# 75%    85.00000
# max    91.00000

# %%
myData = pd.read_csv('byself.csv')

# %%
myData
# Out:
#    Unnamed: 0  Train  Speed     City
# 0           1  12344     54  Kolkata
# 1           2  14789     76   shimla
# 2           3  23456     33    Local
# 3           4  14563     96   bharat

# %%
myData['City'][1]
# Out:
# 'shimla'

# %%
myData['City'][1] = 'Durg'
# Out:
# C:\Users\DMate\AppData\Local\Temp\ipykernel_21560\1838370839.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   myData['City'][1] = 'Durg'
# C:\Users\DMate\AppData\Local\Temp\ipykernel_21560\1838370839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myData['City'][1] = 'Durg'

# %%
myData.to_csv('byself1.csv',index=False)

# %%
readingData = pd.read_csv('byself1.csv')

# %%
readingData
# Out:
#    Unnamed: 0  Train  Speed     City
# 0           1  12344     54  Kolkata
# 1           2  14789     76     Durg
# 2           3  23456     33    Local
# 3           4  14563     96   bharat

# %%
readingData.index = ['first','second','third','fourth']

# %%
readingData
# Out:
#         Unnamed: 0  Train  Speed     City
# first            1  12344     54  Kolkata
# second           2  14789     76     Durg
# third            3  23456     33    Local
# fourth           4  14563     96   bharat

# %%
readingData.shape # Tells you no. of rows & colums.
# Out:
# (4, 4)

# %%
k = readingData.columns # Tells you no of colums and dtype.
print('\n')
print(k,type(k))
# Out:
# Index(['Unnamed: 0', 'Train', 'Speed', 'City'], dtype='object') <class 'pandas.core.indexes.base.Index'>

# %%
readingData.info()
# non-Null Count if all rows showing [ 4 non-null ] then it means all rows entries null value not having.
# not-Null means data frame is good and not empty.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, first to fourth
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4 non-null      int64
#  1   Train       4 non-null      int64
#  2   Speed       4 non-null      int64
#  3   City        4 non-null      object
# dtypes: int64(3), object(1)
# memory usage: 160.0+ bytes

# %% [markdown]
# ### ----------Series & DataFrames------------
# ### > Series are just one column. and one column you did'nt use.
# ### > You use Tabular Data, Two-dimensional, size-mutable, potentially heterogeneous tabular data.

# %%
checkSeries = pd.Series(np.random.rand(5))

# %%
checkSeries
# Out:
# 0    0.867314
# 1    0.247489
# 2    0.047794
# 3    0.433207
# 4    0.103632
# dtype: float64

# %%
type(checkSeries)
# Out:
# pandas.core.series.Series

# %%
newDataFrame = pd.DataFrame([[6,7,9,2],[10,50,60,90]])

# %%
newDataFrame
# Out:
#     0   1   2   3
# 0   6   7   9   2
# 1  10  50  60  90

# %%
type(newDataFrame)
# Out:
# pandas.core.frame.DataFrame

# %%
newDataFrame.describe()
# Out:
#                0          1          2          3
# count   2.000000   2.000000   2.000000   2.000000
# mean    8.000000  28.500000  34.500000  46.000000
# std     2.828427  30.405592  36.062446  62.225397
# min     6.000000   7.000000   9.000000   2.000000
# 25%     7.000000  17.750000  21.750000  24.000000
# 50%     8.000000  28.500000  34.500000  46.000000
# 75%     9.000000  39.250000  47.250000  68.000000
# max    10.000000  50.000000  60.000000  90.000000

# %%
newDataFrame.dtypes
# Out:
# 0    int64
# 1    int64
# 2    int64
# 3    int64
# dtype: object

# %%
newDataFrame.head()
# Out:
#     0   1   2   3
# 0   6   7   9   2
# 1  10  50  60  90

# %%
newDataFrame[0][0] = "Dipesh"
# Out:
# C:\Users\DMate\AppData\Local\Temp\ipykernel_21560\4048979502.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDataFrame[0][0] = "Dipesh"
# C:\Users\DMate\AppData\Local\Temp\ipykernel_21560\4048979502.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Dipesh' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   newDataFrame[0][0] = "Dipesh"

# %%
newDataFrame
# Out:
#         0   1   2   3
# 0  Dipesh   7   9   2
# 1      10  50  60  90

# %%
newDataFrame.dtypes
# Out:
# 0    object
# 1     int64
# 2     int64
# 3     int64
# dtype: object

# %%
newDataFrame.index # gives you  all rows
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
newDataFrame.columns # gives you all columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
newDataFrame.to_numpy() #changes to numpy array
# Out:
# array([['Dipesh', 7, 9, 2],
#        [10, 50, 60, 90]], dtype=object)

# %%
newDataFrame[0][0] = 0.333333333

# %%
newDataFrame
# Out:
#           0   1   2   3
# 0  0.333333   7   9   2
# 1        10  50  60  90

# %%
newDataFrame.dtypes
# Out:
# 0    object
# 1     int64
# 2     int64
# 3     int64
# dtype: object

# %%
newDataFrame.T # Transpose
# Out:
#           0   1
# 0  0.333333  10
# 1         7  50
# 2         9  60
# 3         2  90

# %%
newDataFrame.head()
# Out:
#           0   1   2   3
# 0  0.333333   7   9   2
# 1        10  50  60  90

# %% [raw]
# #### ---- VIEW

# %%
newDFcopy = newDataFrame.copy() #it is a copy

# %%
newDFcopy[0][1] = 'Gauri'
# Out:
# C:\Users\DMate\AppData\Local\Temp\ipykernel_21560\2376160209.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDFcopy[0][1] = 'Gauri'
# C:\Users\DMate\AppData\Local\Temp\ipykernel_21560\2376160209.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDFcopy[0][1] = 'Gauri'

# %%
newDFcopy.head(2)
# Out:
#           0   1   2   3
# 0  0.333333   7   9   2
# 1     Gauri  50  60  90

# %%
newDataFrame.head(2)
# Out:
#           0   1   2   3
# 0  0.333333   7   9   2
# 1        10  50  60  90

# %% [markdown]
# #### newDataFrame & newDFcopy both are different, have diff memory

# %%
newDataFrame.columns = list("ABCDEF") # change of columns names
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 newDataFrame.columns = list("ABCDEF") # change of columns names
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 4 elements, new values have 6 elements

# %%
newDataFrame.head(2)

# %%
newDataFrame.loc[[1,3],['B','D','F']] # does'nt change just return a new df and you can select index Row & colums names.

# %%
newDataFrame.head(2)

# %%
newDataFrame.loc[[1,5] ,:] # for All Rows & Columns use Colon

# %%
newDataFrame.loc[(newDataFrame['A'] < 0.2) | (newDataFrame['C'] > 0.1)]

# %%
newDataFrame.iloc[0,5] # for index selection

# %%
newDataFrame.iloc[[0,6],[1,4]]

# %%
newDataFrame.drop(['A','C'], axis=1) # delete row copy not effect on original

# %%
nd = newDataFrame.drop(['F'],axis=1) # for copy delete row

# %%
nd

# %%
newDataFrame.drop(['F','D'],axis=1, inplace =True) # inplace for originally Deletion

# %%
newDataFrame

# %%
newDataFrame.reset_index(drop=True)
