# %%
import pandas as pd

# %%
import numpy as np

# %%
pip install Quandl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import quandl

# %%
print(quandl)
# Out:
# <module 'quandl' from 'C:\\Users\\DMate\\Documents\\CODING + PROJECTS\\PYTHON PRAC\\myenv\\Lib\\site-packages\\quandl\\__init__.py'>
